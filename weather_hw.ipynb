# %%
#import all dependencies
# !pip install citipy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress
import os
# API keys
# OpenWeatherMap API Key
weather_api_key = "42fc9adc90ea2e2c2fdd3e059f13a8de"
# Google API Key
g_key = "AIzaSyAqKJpKDT8joFxSRi-hVSjmLrx1eHgTZc"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities1.csv"

# Set the Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# Requirement already satisfied: citipy in c:\users\gonza\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\gonza\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
#Create empty sets to later hold data
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %%
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="


# For each city name in cities list
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : alanya
# Processing Record 2 of Set 1 : barrow
# Processing Record 3 of Set 1 : xining
# Processing Record 4 of Set 1 : dikson
# Processing Record 5 of Set 1 : pingliang
# Processing Record 6 of Set 1 : bredasdorp
# Processing Record 7 of Set 1 : fairbanks
# Processing Record 8 of Set 1 : boddam
# Processing Record 9 of Set 1 : hobart
# Processing Record 10 of Set 1 : arraial do cabo
# Processing Record 11 of Set 1 : bethel
# Processing Record 12 of Set 1 : punta arenas
# Processing Record 13 of Set 1 : siilinjarvi
# Processing Record 14 of Set 1 : charagua
# Processing Record 15 of Set 1 : kirakira
# Processing Record 16 of Set 1 : cabo san lucas
# Processing Record 17 of Set 1 : sakakah
# Processing Record 18 of Set 1 : busselton
# Processing Record 19 of Set 1 : leh
# Processing Record 20 of Set 1 : monrovia
# Processing Record 21 of Set 1 : vaini
# Processing Record 22 of Set 1 : worthington
# City not found. Skipping...
# Processing Record 23 of Set 1 : saskylakh
# Processing Record 24 of Set 1 : castro
# Processing Record 25 of Set 1 : eyl
# City not found. Skipping...
# Processing Record 26 of Set 1 : albany
# Processing Record 27 of Set 1 : bama
# Processing Record 28 of Set 1 : puerto ayora
# Processing Record 29 of Set 1 : laguna
# Processing Record 30 of Set 1 : tuktoyaktuk
# Processing Record 31 of Set 1 : santa eulalia
# Processing Record 32 of Set 1 : yairipok
# Processing Record 33 of Set 1 : quijingue
# Processing Record 34 of Set 1 : butaritari
# Processing Record 35 of Set 1 : mataura
# Processing Record 36 of Set 1 : cape town
# Processing Record 37 of Set 1 : ushuaia
# Processing Record 38 of Set 1 : clyde river
# Processing Record 39 of Set 1 : rikitea
# City not found. Skipping...
# Processing Record 40 of Set 1 : komsomolskiy
# City not found. Skipping...
# Processing Record 41 of Set 1 : bluff
# Processing Record 42 of Set 1 : general roca
# Processing Record 43 of Set 1 : kodiak
# Processing Record 44 of Set 1 : atuona
# Processing Record 45 of Set 1 : alexandria
# Processing Record 46 of Set 1 : rawson
# Processing Record 47 of Set 1 : new norfolk
# Processing Record 48 of Set 1 : kichmengskiy gorodok
# Processing Record 49 of Set 1 : airai
# Processing Record 50 of Set 1 : san quintin
# Processing Record 0 of Set 2 : matamoros
# Processing Record 1 of Set 2 : hermanus
# Processing Record 2 of Set 2 : hilo
# Processing Record 3 of Set 2 : kapaa
# Processing Record 4 of Set 2 : temiscaming
# Processing Record 5 of Set 2 : geraldton
# Processing Record 6 of Set 2 : tommot
# Processing Record 7 of Set 2 : provideniya
# Processing Record 8 of Set 2 : mandalgovi
# Processing Record 9 of Set 2 : zhigansk
# Processing Record 10 of Set 2 : santa maria
# Processing Record 11 of Set 2 : upernavik
# City not found. Skipping...
# Processing Record 12 of Set 2 : poquoson
# Processing Record 13 of Set 2 : berlevag
# Processing Record 14 of Set 2 : hofn
# Processing Record 15 of Set 2 : weatherford
# Processing Record 16 of Set 2 : kamariotissa
# Processing Record 17 of Set 2 : bahia honda
# Processing Record 18 of Set 2 : port hardy
# Processing Record 19 of Set 2 : iqaluit
# Processing Record 20 of Set 2 : comodoro rivadavia
# Processing Record 21 of Set 2 : pisco
# Processing Record 22 of Set 2 : batticaloa
# Processing Record 23 of Set 2 : mackay
# Processing Record 24 of Set 2 : ambon
# Processing Record 25 of Set 2 : ron
# Processing Record 26 of Set 2 : kaz
# Processing Record 27 of Set 2 : mayor pablo lagerenza
# Processing Record 28 of Set 2 : harper
# Processing Record 29 of Set 2 : talnakh
# Processing Record 30 of Set 2 : faanui
# Processing Record 31 of Set 2 : sobradinho
# City not found. Skipping...
# Processing Record 32 of Set 2 : surgut
# Processing Record 33 of Set 2 : okha
# Processing Record 34 of Set 2 : puri
# Processing Record 35 of Set 2 : sarande
# City not found. Skipping...
# Processing Record 36 of Set 2 : vao
# City not found. Skipping...
# Processing Record 37 of Set 2 : saldanha
# Processing Record 38 of Set 2 : nishihara
# Processing Record 39 of Set 2 : taoudenni
# Processing Record 40 of Set 2 : nhulunbuy
# Processing Record 41 of Set 2 : mount gambier
# Processing Record 42 of Set 2 : bengkulu
# Processing Record 43 of Set 2 : gwembe
# Processing Record 44 of Set 2 : nikolskoye
# Processing Record 45 of Set 2 : aklavik
# Processing Record 46 of Set 2 : ancud
# Processing Record 47 of Set 2 : kavieng
# Processing Record 48 of Set 2 : olmos
# Processing Record 49 of Set 2 : guerrero negro
# Processing Record 50 of Set 2 : zavetnoye
# Processing Record 0 of Set 3 : tartus
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 of Set 3 : parkersburg
# Processing Record 2 of Set 3 : ust-tsilma
# Processing Record 3 of Set 3 : elko
# City not found. Skipping...
# Processing Record 4 of Set 3 : mar del plata
# Processing Record 5 of Set 3 : balkanabat
# Processing Record 6 of Set 3 : grand gaube
# Processing Record 7 of Set 3 : carutapera
# Processing Record 8 of Set 3 : havoysund
# Processing Record 9 of Set 3 : cukai
# Processing Record 10 of Set 3 : vestmannaeyjar
# Processing Record 11 of Set 3 : samarkand
# Processing Record 12 of Set 3 : jamestown
# Processing Record 13 of Set 3 : camacha
# Processing Record 14 of Set 3 : ribeira grande
# Processing Record 15 of Set 3 : slave lake
# Processing Record 16 of Set 3 : torres
# Processing Record 17 of Set 3 : itarema
# Processing Record 18 of Set 3 : faya
# Processing Record 19 of Set 3 : jalu
# Processing Record 20 of Set 3 : nioki
# Processing Record 21 of Set 3 : orlik
# Processing Record 22 of Set 3 : yellowknife
# Processing Record 23 of Set 3 : alugan
# Processing Record 24 of Set 3 : fort-shevchenko
# Processing Record 25 of Set 3 : chokurdakh
# Processing Record 26 of Set 3 : kodinsk
# Processing Record 27 of Set 3 : alta floresta
# Processing Record 28 of Set 3 : longyearbyen
# Processing Record 29 of Set 3 : basco
# Processing Record 30 of Set 3 : port alfred
# Processing Record 31 of Set 3 : bambous virieux
# Processing Record 32 of Set 3 : diamantino
# Processing Record 33 of Set 3 : hasaki
# Processing Record 34 of Set 3 : salisbury
# Processing Record 35 of Set 3 : shieli
# Processing Record 36 of Set 3 : luganville
# Processing Record 37 of Set 3 : wajima
# Processing Record 38 of Set 3 : tuatapere
# Processing Record 39 of Set 3 : belo oriente
# Processing Record 40 of Set 3 : saint anthony
# Processing Record 41 of Set 3 : krasnoselkup
# Processing Record 42 of Set 3 : henties bay
# Processing Record 43 of Set 3 : vernon
# Processing Record 44 of Set 3 : avarua
# Processing Record 45 of Set 3 : narsaq
# Processing Record 46 of Set 3 : burnie
# Processing Record 47 of Set 3 : tasiilaq
# Processing Record 48 of Set 3 : remontnoye
# Processing Record 49 of Set 3 : tautira
# Processing Record 50 of Set 3 : peniche
# Processing Record 0 of Set 4 : kavaratti
# Processing Record 1 of Set 4 : bandarbeyla
# Processing Record 2 of Set 4 : cam ranh
# Processing Record 3 of Set 4 : randolph
# Processing Record 4 of Set 4 : den helder
# Processing Record 5 of Set 4 : qaanaaq
# Processing Record 6 of Set 4 : carnarvon
# Processing Record 7 of Set 4 : yulara
# City not found. Skipping...
# Processing Record 8 of Set 4 : wells
# Processing Record 9 of Set 4 : thompson
# Processing Record 10 of Set 4 : hithadhoo
# Processing Record 11 of Set 4 : dingle
# Processing Record 12 of Set 4 : yuryevets
# Processing Record 13 of Set 4 : north las vegas
# Processing Record 14 of Set 4 : pavilosta
# City not found. Skipping...
# Processing Record 15 of Set 4 : barabinsk
# Processing Record 16 of Set 4 : gudalur
# Processing Record 17 of Set 4 : khatanga
# Processing Record 18 of Set 4 : san patricio
# Processing Record 19 of Set 4 : pangnirtung
# Processing Record 20 of Set 4 : teya
# Processing Record 21 of Set 4 : east london
# Processing Record 22 of Set 4 : campbell river
# Processing Record 23 of Set 4 : vila franca do campo
# Processing Record 24 of Set 4 : kendari
# Processing Record 25 of Set 4 : quatre cocos
# City not found. Skipping...
# Processing Record 26 of Set 4 : ilebo
# Processing Record 27 of Set 4 : georgetown
# Processing Record 28 of Set 4 : kloulklubed
# Processing Record 29 of Set 4 : namatanai
# Processing Record 30 of Set 4 : mitsamiouli
# Processing Record 31 of Set 4 : erenhot
# Processing Record 32 of Set 4 : saint george
# Processing Record 33 of Set 4 : dali
# Processing Record 34 of Set 4 : bom jesus
# Processing Record 35 of Set 4 : caravelas
# Processing Record 36 of Set 4 : montepuez
# Processing Record 37 of Set 4 : boyuibe
# Processing Record 38 of Set 4 : port lincoln
# Processing Record 39 of Set 4 : alice springs
# Processing Record 40 of Set 4 : paraguacu paulista
# Processing Record 41 of Set 4 : hamilton
# Processing Record 42 of Set 4 : maseru
# Processing Record 43 of Set 4 : torbay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of Set 4 : karratha
# Processing Record 45 of Set 4 : ushumun
# Processing Record 46 of Set 4 : salalah
# Processing Record 47 of Set 4 : tilichiki
# Processing Record 48 of Set 4 : huarmey
# Processing Record 49 of Set 4 : banda aceh
# Processing Record 50 of Set 4 : luderitz
# Processing Record 0 of Set 5 : olafsvik
# Processing Record 1 of Set 5 : pell city
# Processing Record 2 of Set 5 : severo-kurilsk
# Processing Record 3 of Set 5 : mansa
# City not found. Skipping...
# Processing Record 4 of Set 5 : kropotkin
# Processing Record 5 of Set 5 : bodden town
# Processing Record 6 of Set 5 : beringovskiy
# Processing Record 7 of Set 5 : port elizabeth
# Processing Record 8 of Set 5 : los llanos de aridane
# Processing Record 9 of Set 5 : margate
# Processing Record 10 of Set 5 : kungurtug
# Processing Record 11 of Set 5 : banepa
# Processing Record 12 of Set 5 : muroto
# Processing Record 13 of Set 5 : puerto del rosario
# Processing Record 14 of Set 5 : hambantota
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of Set 5 : dhidhdhoo
# Processing Record 16 of Set 5 : dwarka
# Processing Record 17 of Set 5 : saint-philippe
# Processing Record 18 of Set 5 : sao filipe
# Processing Record 19 of Set 5 : bachaquero
# Processing Record 20 of Set 5 : palmer
# Processing Record 21 of Set 5 : isoka
# Processing Record 22 of Set 5 : mogadishu
# Processing Record 23 of Set 5 : kuah
# Processing Record 24 of Set 5 : alyangula
# Processing Record 25 of Set 5 : sarangani
# City not found. Skipping...
# Processing Record 26 of Set 5 : bubaque
# Processing Record 27 of Set 5 : coari
# Processing Record 28 of Set 5 : posse
# Processing Record 29 of Set 5 : lantawan
# Processing Record 30 of Set 5 : manasa
# Processing Record 31 of Set 5 : kupang
# Processing Record 32 of Set 5 : dudinka
# Processing Record 33 of Set 5 : marawi
# City not found. Skipping...
# Processing Record 34 of Set 5 : mandera
# Processing Record 35 of Set 5 : sao felix do xingu
# Processing Record 36 of Set 5 : lebu
# Processing Record 37 of Set 5 : cockburn town
# Processing Record 38 of Set 5 : maceio
# Processing Record 39 of Set 5 : hervey bay
# Processing Record 40 of Set 5 : grimstad
# Processing Record 41 of Set 5 : barra dos coqueiros
# Processing Record 42 of Set 5 : barstow
# Processing Record 43 of Set 5 : iwanai
# Processing Record 44 of Set 5 : tulu bolo
# City not found. Skipping...
# Processing Record 45 of Set 5 : telma
# City not found. Skipping...
# Processing Record 46 of Set 5 : sumbe
# Processing Record 47 of Set 5 : hutchinson
# Processing Record 48 of Set 5 : dongsheng
# Processing Record 49 of Set 5 : kaitangata
# Processing Record 50 of Set 5 : cabildo
# Processing Record 0 of Set 6 : sao cristovao
# Processing Record 1 of Set 6 : touros
# Processing Record 2 of Set 6 : dillon
# Processing Record 3 of Set 6 : pochutla
# Processing Record 4 of Set 6 : takoradi
# City not found. Skipping...
# Processing Record 5 of Set 6 : katsuura
# Processing Record 6 of Set 6 : majene
# Processing Record 7 of Set 6 : kedougou
# Processing Record 8 of Set 6 : carauari
# Processing Record 9 of Set 6 : estelle
# Processing Record 10 of Set 6 : ambilobe
# Processing Record 11 of Set 6 : saint-augustin
# Processing Record 12 of Set 6 : bushehr
# Processing Record 13 of Set 6 : ahuimanu
# Processing Record 14 of Set 6 : petauke
# Processing Record 15 of Set 6 : sistranda
# Processing Record 16 of Set 6 : tual
# Processing Record 17 of Set 6 : skelleftea
# Processing Record 18 of Set 6 : ahipara
# Processing Record 19 of Set 6 : lavrentiya
# Processing Record 20 of Set 6 : kahului
# Processing Record 21 of Set 6 : te anau
# Processing Record 22 of Set 6 : znamenskoye
# Processing Record 23 of Set 6 : cherskiy
# Processing Record 24 of Set 6 : bay roberts
# Processing Record 25 of Set 6 : santa fe
# Processing Record 26 of Set 6 : andenes
# Processing Record 27 of Set 6 : havelock
# Processing Record 28 of Set 6 : mbandaka
# Processing Record 29 of Set 6 : rayong
# Processing Record 30 of Set 6 : cidreira
# Processing Record 31 of Set 6 : binzhou
# Processing Record 32 of Set 6 : sabha
# Processing Record 33 of Set 6 : maarianhamina
# Processing Record 34 of Set 6 : sao jose da coroa grande
# Processing Record 35 of Set 6 : maroantsetra
# Processing Record 36 of Set 6 : kollam
# Processing Record 37 of Set 6 : ponta do sol
# Processing Record 38 of Set 6 : vardo
# Processing Record 39 of Set 6 : port augusta
# Processing Record 40 of Set 6 : constitucion
# Processing Record 41 of Set 6 : roald
# Processing Record 42 of Set 6 : vila velha
# Processing Record 43 of Set 6 : batavia
# Processing Record 44 of Set 6 : tiksi
# Processing Record 45 of Set 6 : sao domingos
# City not found. Skipping...
# Processing Record 46 of Set 6 : marienburg
# Processing Record 47 of Set 6 : souillac
# Processing Record 48 of Set 6 : pevek
# Processing Record 49 of Set 6 : iberia
# Processing Record 50 of Set 6 : kalmunai
# Processing Record 0 of Set 7 : bagdarin
# Processing Record 1 of Set 7 : sri aman
# Processing Record 2 of Set 7 : mahebourg
# Processing Record 3 of Set 7 : isangel
# Processing Record 4 of Set 7 : guangyuan
# Processing Record 5 of Set 7 : ararangua
# Processing Record 6 of Set 7 : portland
# Processing Record 7 of Set 7 : penticton
# Processing Record 8 of Set 7 : sakaiminato
# Processing Record 9 of Set 7 : lagoa
# Processing Record 10 of Set 7 : kulhudhuffushi
# Processing Record 11 of Set 7 : rehoboth
# Processing Record 12 of Set 7 : scarborough
# Processing Record 13 of Set 7 : flin flon
# Processing Record 14 of Set 7 : atar
# Processing Record 15 of Set 7 : yumen
# Processing Record 16 of Set 7 : gualaquiza
# Processing Record 17 of Set 7 : prince rupert
# Processing Record 18 of Set 7 : labuan
# Processing Record 19 of Set 7 : qurayyat
# Processing Record 20 of Set 7 : kaeo
# Processing Record 21 of Set 7 : sorong
# Processing Record 22 of Set 7 : talaya
# Processing Record 23 of Set 7 : tadine
# Processing Record 24 of Set 7 : sohag
# Processing Record 25 of Set 7 : tiarei
# Processing Record 26 of Set 7 : emmett
# Processing Record 27 of Set 7 : sao joao da barra
# Processing Record 28 of Set 7 : udachnyy
# Processing Record 29 of Set 7 : yudong
# Processing Record 30 of Set 7 : san andres
# Processing Record 31 of Set 7 : hobyo
# Processing Record 32 of Set 7 : bulaevo
# City not found. Skipping...
# Processing Record 33 of Set 7 : hammerfest
# Processing Record 34 of Set 7 : yichun
# Processing Record 35 of Set 7 : lompoc
# Processing Record 36 of Set 7 : xucheng
# Processing Record 37 of Set 7 : bilibino
# Processing Record 38 of Set 7 : ostrovnoy
# Processing Record 39 of Set 7 : gwanda
# Processing Record 40 of Set 7 : richards bay
# Processing Record 41 of Set 7 : nha trang
# Processing Record 42 of Set 7 : shemonaikha
# Processing Record 43 of Set 7 : dmitriyevskoye
# Processing Record 44 of Set 7 : naze
# Processing Record 45 of Set 7 : kislyakovskaya
# Processing Record 46 of Set 7 : santa cruz
# Processing Record 47 of Set 7 : san vicente
# Processing Record 48 of Set 7 : neiafu
# Processing Record 49 of Set 7 : hami
# Processing Record 50 of Set 7 : waingapu
# Processing Record 0 of Set 8 : ixtapa
# Processing Record 1 of Set 8 : saint-francois
# Processing Record 2 of Set 8 : jati
# Processing Record 3 of Set 8 : arcachon
# Processing Record 4 of Set 8 : katobu
# Processing Record 5 of Set 8 : omboue
# Processing Record 6 of Set 8 : broadstairs
# Processing Record 7 of Set 8 : dukat
# Processing Record 8 of Set 8 : harlow
# Processing Record 9 of Set 8 : klaksvik
# City not found. Skipping...
# Processing Record 10 of Set 8 : anupgarh
# Processing Record 11 of Set 8 : abu kamal
# Processing Record 12 of Set 8 : kwinana
# Processing Record 13 of Set 8 : sao paulo de olivenca
# City not found. Skipping...
# Processing Record 14 of Set 8 : penzance
# Processing Record 15 of Set 8 : port-gentil
# Processing Record 16 of Set 8 : the pas
# Processing Record 17 of Set 8 : athabasca
# City not found. Skipping...
# Processing Record 18 of Set 8 : ternate
# Processing Record 19 of Set 8 : samarai
# Processing Record 20 of Set 8 : fortuna
# Processing Record 21 of Set 8 : juneau
# Processing Record 22 of Set 8 : asheville
# Processing Record 23 of Set 8 : mana
# Processing Record 24 of Set 8 : tiznit
# Processing Record 25 of Set 8 : laje
# Processing Record 26 of Set 8 : bayir
# Processing Record 27 of Set 8 : emerald
# Processing Record 28 of Set 8 : curup
# Processing Record 29 of Set 8 : payson
# Processing Record 30 of Set 8 : cumana
# Processing Record 31 of Set 8 : sisimiut
# Processing Record 32 of Set 8 : lakes entrance
# Processing Record 33 of Set 8 : gat
# Processing Record 34 of Set 8 : stykkisholmur
# Processing Record 35 of Set 8 : norman wells
# Processing Record 36 of Set 8 : tura
# Processing Record 37 of Set 8 : balykshi
# Processing Record 38 of Set 8 : ketchikan
# Processing Record 39 of Set 8 : biloela
# Processing Record 40 of Set 8 : debre tabor
# Processing Record 41 of Set 8 : dakar
# Processing Record 42 of Set 8 : priiskovyy
# Processing Record 43 of Set 8 : severobaykalsk
# City not found. Skipping...
# Processing Record 44 of Set 8 : codrington
# Processing Record 45 of Set 8 : namibe
# Processing Record 46 of Set 8 : half moon bay
# Processing Record 47 of Set 8 : kostomuksha
# Processing Record 48 of Set 8 : atasu
# Processing Record 49 of Set 8 : asfi
# Processing Record 50 of Set 8 : palizada
# Processing Record 0 of Set 9 : paita
# City not found. Skipping...
# Processing Record 1 of Set 9 : beyneu
# Processing Record 2 of Set 9 : mersing
# Processing Record 3 of Set 9 : rundu
# Processing Record 4 of Set 9 : bondoukou
# Processing Record 5 of Set 9 : carballo
# Processing Record 6 of Set 9 : piet retief
# Processing Record 7 of Set 9 : husavik
# Processing Record 8 of Set 9 : deep river
# Processing Record 9 of Set 9 : olinda
# Processing Record 10 of Set 9 : necochea
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 9 : seymchan
# Processing Record 12 of Set 9 : riyadh
# Processing Record 13 of Set 9 : baracoa
# Processing Record 14 of Set 9 : chuy
# Processing Record 15 of Set 9 : goba
# Processing Record 16 of Set 9 : kitimat
# Processing Record 17 of Set 9 : umm lajj
# Processing Record 18 of Set 9 : labytnangi
# Processing Record 19 of Set 9 : laminusa
# Processing Record 20 of Set 9 : borogontsy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 21 of Set 9 : oussouye
# City not found. Skipping...
# Processing Record 22 of Set 9 : puerto maldonado
# Processing Record 23 of Set 9 : yerbogachen
# Processing Record 24 of Set 9 : santiago de cuba
# Processing Record 25 of Set 9 : tocache
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 9 : singapore
# Processing Record 27 of Set 9 : coahuayana
# Processing Record 28 of Set 9 : port hedland
# Processing Record 29 of Set 9 : broken hill
# Processing Record 30 of Set 9 : toccoa
# Processing Record 31 of Set 9 : lorengau
# Processing Record 32 of Set 9 : roebourne
# Processing Record 33 of Set 9 : toora-khem
# Processing Record 34 of Set 9 : mandurah
# Processing Record 35 of Set 9 : biak
# Processing Record 36 of Set 9 : shimoda
# Processing Record 37 of Set 9 : santo andre
# Processing Record 38 of Set 9 : progreso
# Processing Record 39 of Set 9 : tazovskiy
# Processing Record 40 of Set 9 : price
# Processing Record 41 of Set 9 : nouadhibou
# Processing Record 42 of Set 9 : bereda
# Processing Record 43 of Set 9 : gamba
# Processing Record 44 of Set 9 : kathu
# City not found. Skipping...
# Processing Record 45 of Set 9 : sinnamary
# Processing Record 46 of Set 9 : kenora
# Processing Record 47 of Set 9 : trofors
# Processing Record 48 of Set 9 : bowen
# Processing Record 49 of Set 9 : parrita
# Processing Record 50 of Set 9 : belmonte
# Processing Record 0 of Set 10 : antalaha
# Processing Record 1 of Set 10 : port blair
# Processing Record 2 of Set 10 : yaan
# Processing Record 3 of Set 10 : chachapoyas
# Processing Record 4 of Set 10 : kutoarjo
# Processing Record 5 of Set 10 : mount isa
# City not found. Skipping...
# Processing Record 6 of Set 10 : mekhe
# City not found. Skipping...
# Processing Record 7 of Set 10 : dzhalil
# Processing Record 8 of Set 10 : handia
# Processing Record 9 of Set 10 : reconquista
# Processing Record 10 of Set 10 : santa luzia
# Processing Record 11 of Set 10 : saint-esteve
# Processing Record 12 of Set 10 : tianpeng
# Processing Record 13 of Set 10 : vuktyl
# City not found. Skipping...
# Processing Record 14 of Set 10 : novska
# Processing Record 15 of Set 10 : strezhevoy
# Processing Record 16 of Set 10 : tignere
# Processing Record 17 of Set 10 : petropavlovsk-kamchatskiy
# Processing Record 18 of Set 10 : pleshanovo
# City not found. Skipping...
# Processing Record 19 of Set 10 : srednekolymsk
# Processing Record 20 of Set 10 : chulman
# Processing Record 21 of Set 10 : wixom
# Processing Record 22 of Set 10 : kirkwall
# Processing Record 23 of Set 10 : gallup
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 10 : ahvaz
# Processing Record 25 of Set 10 : yankton
# Processing Record 26 of Set 10 : tornio
# Processing Record 27 of Set 10 : santa rosa
# Processing Record 28 of Set 10 : pirovskoye
# City not found. Skipping...
# Processing Record 29 of Set 10 : moose factory
# Processing Record 30 of Set 10 : bathsheba
# Processing Record 31 of Set 10 : pimentel
# Processing Record 32 of Set 10 : aswan
# Processing Record 33 of Set 10 : buraydah
# City not found. Skipping...
# Processing Record 34 of Set 10 : timra
# Processing Record 35 of Set 10 : prieska
# Processing Record 36 of Set 10 : angoche
# Processing Record 37 of Set 10 : telc
# Processing Record 38 of Set 10 : kamenka
# Processing Record 39 of Set 10 : lazaro cardenas
# Processing Record 40 of Set 10 : simao
# Processing Record 41 of Set 10 : rognan
# Processing Record 42 of Set 10 : rafai
# Processing Record 43 of Set 10 : auki
# Processing Record 44 of Set 10 : ballina
# Processing Record 45 of Set 10 : haines junction
# Processing Record 46 of Set 10 : shevchenkove
# Processing Record 47 of Set 10 : analipsis
# Processing Record 48 of Set 10 : port macquarie
# Processing Record 49 of Set 10 : catemaco
# Processing Record 50 of Set 10 : kruisfontein
# Processing Record 0 of Set 11 : olga
# Processing Record 1 of Set 11 : kota belud
# Processing Record 2 of Set 11 : sena madureira
# Processing Record 3 of Set 11 : vila
# Processing Record 4 of Set 11 : baoding
# Processing Record 5 of Set 11 : kieta
# Processing Record 6 of Set 11 : sheltozero
# Processing Record 7 of Set 11 : pangkalanbuun
# Processing Record 8 of Set 11 : panalingaan
# City not found. Skipping...
# Processing Record 9 of Set 11 : lata
# City not found. Skipping...
# Processing Record 10 of Set 11 : soria
# Processing Record 11 of Set 11 : araouane
# Processing Record 12 of Set 11 : zonguldak
# Processing Record 13 of Set 11 : ilulissat
# Processing Record 14 of Set 11 : akyab
# Processing Record 15 of Set 11 : saint stephen
# Processing Record 16 of Set 11 : tabou
# Processing Record 17 of Set 11 : kamenskiy
# Processing Record 18 of Set 11 : inverell
# Processing Record 19 of Set 11 : urengoy
# Processing Record 20 of Set 11 : chietla
# City not found. Skipping...
# Processing Record 21 of Set 11 : dubbo
# Processing Record 22 of Set 11 : la ronge
# Processing Record 23 of Set 11 : chardara
# Processing Record 24 of Set 11 : coffs harbour
# Processing Record 25 of Set 11 : saint-joseph
# Processing Record 26 of Set 11 : birjand
# Processing Record 27 of Set 11 : broome
# Processing Record 28 of Set 11 : pizarro
# Processing Record 29 of Set 11 : consolacion del sur
# Processing Record 30 of Set 11 : meulaboh
# Processing Record 31 of Set 11 : blagoveshchenka
# Processing Record 32 of Set 11 : san pedro de macoris
# Processing Record 33 of Set 11 : suining
# Processing Record 34 of Set 11 : nome
# Processing Record 35 of Set 11 : baculin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a panda data frame using data retrieved
weather_dict = pd.DataFrame({ 
                "City" : city_name_list,
                "Cloudiness" : cloudiness_list,
                "Country" : country_list,
                "Date" : date_list,
                "Humidity" : humidity_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Wind Speed" : wind_speed_list
})

# %%
# Count data (545 for each one)
weather_dict.count()
#Display the Data Frame
weather_dict
# Out:
#                      City  Cloudiness Country        Date  Humidity    Lat  \
# 0                  Alanya          40      TR  1607128454        93  36.54
# 1                  Barrow          90      US  1607128454        78  71.29
# 2                  Xining          39      CN  1607128238        86  36.62
# 3                  Dikson          96      RU  1607128236        94  73.51
# 4               Pingliang          72      CN  1607128227        94  35.54
# ..                    ...         ...     ...         ...       ...    ...
# 540       Blagoveshchenka          16      RU  1607128550        92  52.83
# 541  San Pedro de Macorís          40      DO  1607128550        88  18.46
# 542               Suining          18      CN  1607128550        78  30.51
# 543                  Nome          90      US  1607128551        79  64.50
# 544               Baculin           2      PH  1607128551        67   7.45
#
#         Lng  Max Temp  Wind Speed
# 0     32.00     51.80        3.36
# 1   -156.79     12.20       20.80
# 2    101.77     17.92        2.95
# 3     80.55     25.88       18.52
# 4    106.69     18.09        1.21
# ..      ...       ...         ...
# 540   79.87     -1.37        7.27
# 541  -69.30     77.00        4.70
# 542  105.57     45.18        2.62
# 543 -165.41     24.80       12.75
# 544  126.58     85.66        4.72
#
# [545 rows x 9 columns]

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "blue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")
# Set y axis limit

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# %%
# Create Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "red", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# %%
# Create Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# %%
# Create Latitude vs. Wind Speed scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "green", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (mph)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-10,50)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_dict.loc[weather_dict["Lat"] >= 0]
southern_hemisphere = weather_dict.loc[weather_dict["Lat"] < 0]
# Define function for creating linear regression and scatter plot
def linear_regression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotating(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %%
# Call an function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Call an function #2
annotating(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")
# Out:
# The r-squared is : -0.85
# Text(0, 0.5, 'Max Temp (F)')

# %%
# Call an function #1
equation = linear_regression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

# Call an function #2
annotating(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")
# Out:
# The r-squared is : 0.51
# Text(0, 0.5, 'Max Temp (F)')

# %%
# Call an function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call an function #2
annotating(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")
# Out:
# The r-squared is : 0.21
# Text(0, 0.5, 'Humidity (%)')

# %%
# Call an function #1
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call an function #2
annotating(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")
# Out:
# The r-squared is : 0.38
# Text(0, 0.5, 'Humidity (%)')

# %%
# Call an function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Call an function #2
annotating(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")
# Out:
# The r-squared is : 0.18
# Text(0, 0.5, 'Cloudiness (%)')

# %%
# Call an function #1
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call an function #2
annotating(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")
# Out:
# The r-squared is : 0.08
# Text(0, 0.5, 'Cloudiness (%)')

# %%
# Call an function #1
equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call an function #2
annotating(equation, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")
# Out:
# The r-squared is : 0.16
# Text(0, 0.5, 'Wind Speed (mph)')

# %%
# Call an function #1
equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Call an function #2
annotating(equation, -30, 15)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.32
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-8d5ea05229f3> in <module>
#      15
#      16 # Save the figure
# ---> 17 plt.savefig("../Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     727 def savefig(*args, **kwargs):
#     728     fig = gcf()
# --> 729     res = fig.savefig(*args, **kwargs)
#     730     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     731     return res
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2178             self.patch.set_visible(frameon)
#    2179
# -> 2180         self.canvas.print_figure(fname, **kwargs)
#    2181
#    2182         if frameon:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2089                     orientation=orientation,
#    2090                     bbox_inches_restore=_bbox_inches_restore,
# -> 2091                     **kwargs)
#    2092             finally:
#    2093                 if bbox_inches and restore_bbox:
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
# --> 530                     cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     531                 _png.write_png(renderer._renderer, fh,
#     532                                self.figure.dpi, metadata=metadata)
#
# ~\Anaconda3\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     445 def open_file_cm(path_or_file, mode="r", encoding=None):
#     446     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 447     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     448     if opened:
#     449         with fh:
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     430             fh = bz2.BZ2File(fname, flag)
#     431         else:
# --> 432             fh = open(fname, flag, encoding=encoding)
#     433         opened = True
#     434     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png'
